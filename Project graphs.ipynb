# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv("final_filtered_recipes.csv")

# Show first 5 rows
print(df.head())



plt.figure()
plt.bar(matched_recipes["recipe"], matched_recipes["health_score"])

plt.xlabel("Recipes")
plt.ylabel("Health Score")
plt.title("Health Score of Matching Recipes")

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
# Out:
#                                  recipe_title        subcategory  \
# 0  Air Fryer Potato Slices with Dipping Sauce  Air Fryer Recipes
# 1  Air Fryer Everything Bagel Chicken Cutlets  Air Fryer Recipes
# 2                    Air Fryer Peanut Chicken  Air Fryer Recipes
# 3                    Air Fryer Sauteed Onions  Air Fryer Recipes
# 4          Air Fryer English Muffin Tuna Melt  Air Fryer Recipes
#
#                                          ingredients  \
# 0  ["3/4 cup ketchup", "1/2 cup beer", "1 tablesp...
# 1  ["4 chicken cutlets (about 1 pound total)", "s...
# 2  ["2 tablespoons Thai sweet chili sauce", "1 ta...
# 3  ["1 large onion", "1 1/2 teaspoons olive oil",...
# 4  ["2 English muffins", "2 (5-ounce) cans tuna",...
#
#                                           directions  num_ingredients  \
# 0  ["Combine ketchup, beer, Worcestershire sauce,...                9
# 1  ["Preheat an air fryer to 400 degrees F (200 d...                9
# ...
